# %%
import pandas as pd
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt
sb.set() # set the default Seaborn style for graphics

# %%
player = pd.read_csv("newplayer.csv")

# %%
player.sort_values(["player_id","year","month"], ascending = [True,False,False], inplace = True)
player.reset_index(inplace = True)
player.drop(labels = ["index","level_0"], axis = "columns", inplace = True)
player
# Out:
#         player_id        player_name   birthday  height  weight  birthyear  \
# 0            2625  Patryk Rachwal,18  1/27/1981  175.26     154       1981
# 1            2625  Patryk Rachwal,18  1/27/1981  175.26     154       1981
# 2            2625  Patryk Rachwal,18  1/27/1981  175.26     154       1981
# 3            2625  Patryk Rachwal,18  1/27/1981  175.26     154       1981
# 4            2625  Patryk Rachwal,18  1/27/1981  175.26     154       1981
# ...           ...                ...        ...     ...     ...        ...
# 183137     750435     Rees Greenwood  1/20/1996  172.72     150       1996
# 183138     750435     Rees Greenwood  1/20/1996  172.72     150       1996
# 183139     750435     Rees Greenwood  1/20/1996  172.72     150       1996
# 183140     750584  Alexandre Azevedo  1/28/1997  175.26     150       1997
# 183141     750584  Alexandre Azevedo  1/28/1997  175.26     150       1997
#
#         birthmonth       date  overall_rating  potential  ...  year month  \
# 0                1  1/16/2015              61         61  ...  2015     1
# 1                1  11/7/2014              61         61  ...  2014    11
# 2                1  9/18/2014              61         61  ...  2014     9
# 3                1   6/7/2013              61         61  ...  2013     6
# 4                1   3/8/2013              61         61  ...  2013     3
# ...            ...        ...             ...        ...  ...   ...   ...
# 183137           1   2/6/2015              56         70  ...  2015     2
# 183138           1  1/16/2015              56         70  ...  2015     1
# 183139           1  2/22/2007              56         70  ...  2007     2
# 183140           1  5/19/2016              58         66  ...  2016     5
# 183141           1  2/22/2007              58         66  ...  2007     2
#
#               age  age_rounded  max_rating  max_idx  max_age  abs_growth  \
# 0       34.000000           34          63   139855       27         0.0
# 1       33.833333           34          63   139855       27         0.0
# 2       33.666667           34          63   139855       27         0.0
# 3       32.416667           32          63   139855       27         0.0
# 4       32.166667           32          63   139855       27         0.0
# ...           ...          ...         ...      ...      ...         ...
# 183137  19.083333           19          60   147408       20         0.0
# 183138  19.000000           19          60   147408       20         0.0
# 183139  11.083333           11          60   147408       20         0.0
# 183140  19.333333           19          58     8085       19         0.0
# 183141  10.083333           10          58     8085       19         0.0
#
#         perc_growth  year_elapsed
# 0               0.0      0.000000
# 1               0.0     -0.166667
# 2               0.0     -0.333333
# 3               0.0     -1.583333
# 4               0.0     -1.833333
# ...             ...           ...
# 183137          0.0      0.083333
# 183138          0.0      0.000000
# 183139          0.0     -7.916667
# 183140          0.0      9.250000
# 183141          0.0      0.000000
#
# [183142 rows x 56 columns]

# %%
player.sort_index(inplace = True)
player
# Out:
#         player_id         player_name   birthday  height  weight  birthyear  \
# 0          505942  Aaron Appindangoye  2/29/1992  182.88     187       1992
# 1          505942  Aaron Appindangoye  2/29/1992  182.88     187       1992
# 2          505942  Aaron Appindangoye  2/29/1992  182.88     187       1992
# 3          505942  Aaron Appindangoye  2/29/1992  182.88     187       1992
# 4          505942  Aaron Appindangoye  2/29/1992  182.88     187       1992
# ...           ...                 ...        ...     ...     ...        ...
# 183137      39902  Zvjezdan Misimovic   6/5/1982  180.34     176       1982
# 183138      39902  Zvjezdan Misimovic   6/5/1982  180.34     176       1982
# 183139      39902  Zvjezdan Misimovic   6/5/1982  180.34     176       1982
# 183140      39902  Zvjezdan Misimovic   6/5/1982  180.34     176       1982
# 183141      39902  Zvjezdan Misimovic   6/5/1982  180.34     176       1982
#
#         birthmonth        date  overall_rating  potential  ...  year month  \
# 0                2   2/18/2016              67         71  ...  2016     2
# 1                2  11/19/2015              67         71  ...  2015    11
# 2                2   9/21/2015              62         66  ...  2015     9
# 3                2   3/20/2015              61         65  ...  2015     3
# 4                2   2/22/2007              61         65  ...  2007     2
# ...            ...         ...             ...        ...  ...   ...   ...
# 183137           6   8/30/2009              83         85  ...  2009     8
# 183138           6   2/22/2009              78         80  ...  2009     2
# 183139           6   8/30/2008              77         80  ...  2008     8
# 183140           6   8/30/2007              78         81  ...  2007     8
# 183141           6   2/22/2007              80         81  ...  2007     2
#
#               age  age_rounded  max_rating  max_idx  max_age  abs_growth  \
# 0       24.000000           24          67        0       24         6.0
# 1       23.750000           24          67        0       24         6.0
# 2       23.583333           24          67        0       24         1.0
# 3       23.083333           23          67        0       24         0.0
# 4       15.000000           15          67        0       24         0.0
# ...           ...          ...         ...      ...      ...         ...
# 183137  27.166667           27          83   183972       28         2.5
# 183138  26.666667           27          83   183972       28         2.0
# 183139  26.166667           26          83   183972       28         1.5
# 183140  25.166667           25          83   183972       28         0.5
# 183141  24.666667           25          83   183972       28         0.0
#
#         perc_growth  year_elapsed
# 0          9.836066      9.000000
# 1          9.836066      8.750000
# 2          1.639344      8.583333
# 3          0.000000      8.083333
# 4          0.000000      0.000000
# ...             ...           ...
# 183137     3.125000      2.500000
# 183138     2.500000      2.000000
# 183139     1.875000      1.500000
# 183140     0.625000      0.500000
# 183141     0.000000      0.000000
#
# [183142 rows x 56 columns]

# %%
pd.DataFrame(player["perc_growth"]).describe()
# Out:
#          perc_growth
# count  183142.000000
# mean        9.604551
# std        14.310400
# min       -33.962264
# 25%         0.000000
# 50%         5.882353
# 75%        16.417910
# max       118.181818

# %%
droplist = []
test = player.copy()
i =0 
while i < test.shape[0]:
    if not test.loc[i, "overall_rating"] > 30:
        droplist.append(i)
    i += 1
print(droplist)
# Out:
# [483, 983, 1752, 2089, 2482, 2498, 2540, 3283, 4006, 4202, 4593, 4801, 4998, 5120, 5279, 5395, 5751, 7341, 7421, 7452, 7454, 7455, 7458, 7470, 7471, 7527, 8042, 8064, 8084, 8186, 8253, 9055, 9176, 9353, 9376, 9647, 9726, 9919, 10784, 11283, 11718, 11863, 11897, 12019, 12270, 12298, 12368, 12484, 12949, 12997, 13025, 13335, 13532, 13632, 13659, 13905, 14046, 14246, 14291, 14322, 14740, 14766, 15032, 15141, 15173, 15587, 15636, 16285, 16421, 16792, 16912, 17100, 17155, 17262, 17583, 17659, 17928, 18144, 18251, 18330, 18889, 19060, 19095, 19269, 19309, 19373, 19760, 19786, 20114, 20482, 20941, 21152, 21311, 21644, 21788, 21847, 22270, 22778, 22805, 23243, 23365, 23647, 23677, 25077, 25085, 25325, 25527, 25561, 25872, 26045, 26195, 26218, 26336, 26464, 26543, 26787, 27239, 27262, 27312, 27459, 27623, 28183, 28324, 28349, 28439, 28510, 28708, 29018, 29664, 29790, 30029, 30080, 30341, 30428, 30466, 30505, 31185, 31247, 31579, 31732, 32115, 33284, 33437, 33749, 33942, 34082, 34251, 35343, 35491, 35523, 35762, 36374, 36575, 36820, 37098, 37238, 37366, 37912, 38137, 38161, 39020, 39158, 39337, 39369, 39398, 39442, 39463, 39773, 39995, 40177, 40186, 40427, 40645, 40737, 40968, 41076, 41513, 41540, 41717, 41752, 41787, 41847, 41985, 42352, 42390, 42855, 43071, 43137, 43417, 43489, 43660, 44138, 44575, 44667, 45246, 45272, 45439, 45668, 45715, 46480, 46680, 46824, 46837, 47023, 47200, 47443, 47925, 47962, 47980, 48049, 48204, 48241, 48431, 48582, 48901, 48930, 48980, 49137, 49384, 49595, 49779, 50456, 50650, 50962, 51008, 51422, 51471, 51648, 51839, 52179, 53605, 53676, 54099, 54120, 54241, 54772, 54959, 55551, 55617, 56194, 56583, 56627, 56757, 56938, 57337, 57549, 57760, 58149, 58221, 58360, 58381, 58636, 59312, 59626, 59689, 59778, 60356, 60477, 60548, 60731, 61070, 61624, 61660, 61810, 62135, 62165, 62693, 63003, 63711, 64218, 64235, 64376, 64693, 65094, 65186, 65283, 65348, 65717, 65807, 66535, 66779, 66966, 67065, 67215, 67346, 67400, 67583, 67650, 67695, 68206, 68259, 68766, 69536, 69745, 69889, 69931, 70051, 70288, 70931, 71316, 71553, 71808, 73319, 73412, 73789, 74389, 74528, 74542, 74987, 75260, 75445, 75701, 75783, 75871, 76886, 77032, 77635, 77791, 77861, 77887, 78188, 78414, 78462, 78665, 78996, 79206, 79247, 79406, 79414, 80025, 80080, 80562, 80776, 81260, 81442, 81550, 81663, 81677, 81728, 81930, 82156, 82188, 82313, 82700, 82845, 83415, 83588, 84281, 84498, 84709, 84710, 84711, 84713, 84714, 84715, 84716, 84717, 84785, 84967, 85101, 85126, 85926, 86000, 86243, 86273, 86401, 86441, 87253, 87582, 87620, 87650, 88123, 88558, 88581, 89363, 89470, 90006, 90600, 90615, 90736, 90766, 90946, 90990, 91066, 91180, 91250, 91885, 91978, 92019, 92037, 92050, 92124, 92160, 92164, 92382, 92496, 92888, 93198, 93580, 93785, 93850, 93858, 94250, 94268, 94561, 95612, 96208, 97276, 97807, 98274, 98364, 98857, 99840, 100000, 100198, 100297, 100343, 100744, 101245, 101678, 101819, 101924, 102005, 102042, 102405, 102459, 102541, 103087, 103531, 103541, 104143, 104659, 104876, 104881, 105235, 105255, 105339, 105521, 105701, 106903, 107369, 107451, 107524, 107745, 107787, 107788, 107789, 107790, 107791, 107794, 107795, 107797, 107798, 107799, 107800, 107801, 108332, 108454, 108464, 108869, 109475, 109507, 109548, 109685, 109762, 110326, 110702, 110793, 110890, 110898, 110944, 110971, 111502, 111608, 112011, 112337, 112608, 112632, 112755, 112787, 113188, 113267, 113301, 113336, 113598, 113824, 114030, 114233, 114262, 114285, 114307, 114364, 114503, 114550, 114597, 115270, 115429, 115459, 115988, 116178, 116590, 116611, 117227, 117259, 117273, 117331, 118504, 118601, 118923, 119173, 119639, 119771, 119964, 119975, 120689, 120724, 120797, 121278, 121331, 122084, 122417, 122633, 122777, 123095, 123156, 123243, 123481, 123526, 123559, 123917, 124118, 124573, 124932, 125065, 125091, 125433, 125520, 126195, 126334, 126385, 126654, 126803, 126906, 127026, 127162, 127234, 127621, 127810, 128096, 128373, 128729, 129169, 129411, 129473, 129586, 129797, 1297 ...

# %%
player = player.drop(droplist)

# %%
i = 0
while i < player.shape[0]:
    playerid = player.loc[i,"player_id"]
    j = i
    while  player.loc[j,"player_id"] == playerid:
        j += 1
    firstrating = player.loc[j-1,"overall_rating"]
    while not firstrating > 30:
        j -= 1
        firstrating = player.loc[j-1,"overall_rating"]
    startyear = player.loc[j-1, "year"] + player.loc[j-1, "month"]/12
    for k in range(i,j):
        player.loc[k,'abs_growth'] = player.loc[k,"overall_rating"] - firstrating
        player.loc[k,'perc_growth'] = 100*player.loc[k,"abs_growth"]/firstrating
        currentyear = player.loc[k, "year"] + player.loc[k, "month"]/12
        player.loc[k,'year_elapsed'] = currentyear - startyear
        player.loc[k,'start_rating'] = firstrating
    i = j
    if i == player.shape[0] or j == player.shape[0]:
        break
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\range.py in get_loc(self, key, method, tolerance)
#     349             try:
# --> 350                 return self._range.index(new_key)
#     351             except ValueError:
#
# ValueError: 183142 is not in range
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-189-57528bbfe850> in <module>
#       3     playerid = player.loc[i,"player_id"]
#       4     j = i
# ----> 5     while  player.loc[j,"player_id"] == playerid:
#       6         j += 1
#       7     firstrating = player.loc[j-1,"overall_rating"]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1760                 except (KeyError, IndexError, AttributeError):
#    1761                     pass
# -> 1762             return self._getitem_tuple(key)
#    1763         else:
#    1764             # we by definition only have the 0th axis
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#    1270     def _getitem_tuple(self, tup: Tuple):
#    1271         try:
# -> 1272             return self._getitem_lowerdim(tup)
#    1273         except IndexingError:
#    1274             pass
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_lowerdim(self, tup)
#    1387         for i, key in enumerate(tup):
#    1388             if is_label_like(key) or isinstance(key, tuple):
# -> 1389                 section = self._getitem_axis(key, axis=i)
#    1390
#    1391                 # we have yielded a scalar ?
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1963         # fall thru to straight lookup
#    1964         self._validate_key(key, axis)
# -> 1965         return self._get_label(key, axis=axis)
#    1966
#    1967
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _get_label(self, label, axis)
#     623             raise IndexingError("no slices here, handle elsewhere")
#     624
# --> 625         return self.obj._xs(label, axis=axis)
#     626
#     627     def _get_loc(self, key: int, axis: int):
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in xs(self, key, axis, level, drop_level)
#    3535             loc, new_index = self.index.get_loc_level(key, drop_level=drop_level)
#    3536         else:
# -> 3537             loc = self.index.get_loc(key)
#    3538
#    3539             if isinstance(loc, np.ndarray):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\range.py in get_loc(self, key, method, tolerance)
#     350                 return self._range.index(new_key)
#     351             except ValueError:
# --> 352                 raise KeyError(key)
#     353         return super().get_loc(key, method=method, tolerance=tolerance)
#     354
#
# KeyError: 183142

# %%
i = 0
while i < player.shape[0]:
    playerid = player.loc[i,"player_id"]
    j = i
    while  player.loc[j,"player_id"] == playerid:
        j += 1
    firstrating = player.loc[j-1,"overall_rating"]
    while not firstrating > 30:
        j -= 1
        firstrating = player.loc[j-1,"overall_rating"]
    for k in range(i,j):
        
    i = j
    if i == player.shape[0] or j == player.shape[0]:
        break
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\range.py in get_loc(self, key, method, tolerance)
#     349             try:
# --> 350                 return self._range.index(new_key)
#     351             except ValueError:
#
# ValueError: 183142 is not in range
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-204-1777d2f8a805> in <module>
#       3     playerid = player.loc[i,"player_id"]
#       4     j = i
# ----> 5     while  player.loc[j,"player_id"] == playerid:
#       6         j += 1
#       7     firstrating = player.loc[j-1,"overall_rating"]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1760                 except (KeyError, IndexError, AttributeError):
#    1761                     pass
# -> 1762             return self._getitem_tuple(key)
#    1763         else:
#    1764             # we by definition only have the 0th axis
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#    1270     def _getitem_tuple(self, tup: Tuple):
#    1271         try:
# -> 1272             return self._getitem_lowerdim(tup)
#    1273         except IndexingError:
#    1274             pass
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_lowerdim(self, tup)
#    1387         for i, key in enumerate(tup):
#    1388             if is_label_like(key) or isinstance(key, tuple):
# -> 1389                 section = self._getitem_axis(key, axis=i)
#    1390
#    1391                 # we have yielded a scalar ?
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1963         # fall thru to straight lookup
#    1964         self._validate_key(key, axis)
# -> 1965         return self._get_label(key, axis=axis)
#    1966
#    1967
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _get_label(self, label, axis)
#     623             raise IndexingError("no slices here, handle elsewhere")
#     624
# --> 625         return self.obj._xs(label, axis=axis)
#     626
#     627     def _get_loc(self, key: int, axis: int):
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in xs(self, key, axis, level, drop_level)
#    3535             loc, new_index = self.index.get_loc_level(key, drop_level=drop_level)
#    3536         else:
# -> 3537             loc = self.index.get_loc(key)
#    3538
#    3539             if isinstance(loc, np.ndarray):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\range.py in get_loc(self, key, method, tolerance)
#     350                 return self._range.index(new_key)
#     351             except ValueError:
# --> 352                 raise KeyError(key)
#     353         return super().get_loc(key, method=method, tolerance=tolerance)
#     354
#
# KeyError: 183142

# %%
player2 = player.copy()
player2.drop(player2[player2.year_elapsed > 5].index, inplace = True)

# %%
player2["year_elapsed"] = player2["year_elapsed"].round(0)
player2
# Out:
#         player_id        player_name   birthday  height  weight  birthyear  \
# 7            2625  Patryk Rachwal,18  1/27/1981  175.26     154       1981
# 8            2625  Patryk Rachwal,18  1/27/1981  175.26     154       1981
# 9            2625  Patryk Rachwal,18  1/27/1981  175.26     154       1981
# 10           2625  Patryk Rachwal,18  1/27/1981  175.26     154       1981
# 11           2625  Patryk Rachwal,18  1/27/1981  175.26     154       1981
# ...           ...                ...        ...     ...     ...        ...
# 183126     744907        Greg Taylor  11/5/1997  172.72     137       1997
# 183128     746419   Francisco Afonso  4/24/1997  175.26     152       1997
# 183130     748432     Fynn Arkenberg   3/4/1996  187.96     176       1996
# 183139     750435     Rees Greenwood  1/20/1996  172.72     150       1996
# 183141     750584  Alexandre Azevedo  1/28/1997  175.26     150       1997
#
#         birthmonth       date  overall_rating  potential  ... month  \
# 7                1  2/22/2012              58         58  ...     2
# 8                1  8/30/2011              58         58  ...     8
# 9                1  2/22/2011              59         63  ...     2
# 10               1  8/30/2010              60         64  ...     8
# 11               1  8/30/2008              60         64  ...     8
# ...            ...        ...             ...        ...  ...   ...
# 183126          11  2/22/2007              51         65  ...     2
# 183128           4  2/22/2007              59         66  ...     2
# 183130           3  2/22/2007              58         68  ...     2
# 183139           1  2/22/2007              56         70  ...     2
# 183141           1  2/22/2007              58         66  ...     2
#
#               age age_rounded  max_rating  max_idx  max_age  abs_growth  \
# 7       31.083333          31          63   139855       27        -5.0
# 8       30.583333          31          63   139855       27        -5.0
# 9       30.083333          30          63   139855       27        -4.0
# 10      29.583333          30          63   139855       27        -3.0
# 11      27.583333          28          63   139855       27        -3.0
# ...           ...         ...         ...      ...      ...         ...
# 183126   9.250000           9          53    66601       19         0.0
# 183128   9.833333          10          59    58304       19         0.0
# 183130  10.916667          11          58    60179       20         0.0
# 183139  11.083333          11          60   147408       20         0.0
# 183141  10.083333          10          58     8085       19         0.0
#
#         perc_growth  year_elapsed  start_rating
# 7         -7.936508           5.0            63
# 8         -7.936508           4.0            63
# 9         -6.349206           4.0            63
# 10        -4.761905           4.0            63
# 11        -4.761905           2.0            63
# ...             ...           ...           ...
# 183126     0.000000           0.0            51
# 183128     0.000000           0.0            59
# 183130     0.000000           0.0            58
# 183139     0.000000           0.0            56
# 183141     0.000000           0.0            58
#
# [59113 rows x 57 columns]

# %%
f = plt.figure(figsize = (15,15))
g = sb.boxplot(data = player2[player2.age < 25], y = "perc_growth", x = "year_elapsed")
g.set_title("Change (%) in Overall Rating over time (5 years)", fontsize = 35)
g.set_xlabel("Years elapsed", fontsize = 30)
g.set_ylabel("Percentage Change in Overall Rating", fontsize = 30)
g.tick_params(labelsize = 25)

# %%
player3 = player2.copy()
player3.drop(player2[player2.age < 18].index, inplace = True)
f = plt.figure(figsize = (15,15))
g = sb.boxplot(data = player3, y = "perc_growth", x = "age_rounded")
g.set_title("Change since start (%) in Overall Rating at each age (5 years)", fontsize = 25)
g.set_xlabel("Age", fontsize = 25)
g.set_ylabel("Change (%) in Overall Rating", fontsize = 25)
g.tick_params(labelsize = 20)

# %%
f, axes = plt.subplots(4,2,figsize = (15,30))
sb.boxplot(data = player2[player2.age == 18], x = "start_rating", y = "perc_growth", ax = axes[0,0])
sb.boxplot(data = player2[player2.age == 19], x = "start_rating", y = "perc_growth", ax = axes[0,1])
sb.boxplot(data = player2[player2.age == 20], x = "start_rating", y = "perc_growth", ax = axes[1,0])
sb.boxplot(data = player2[player2.age == 21], x = "start_rating", y = "perc_growth", ax = axes[1,1])
sb.boxplot(data = player2[player2.age == 22], x = "start_rating", y = "perc_growth", ax = axes[2,0])
sb.boxplot(data = player2[player2.age == 23], x = "start_rating", y = "perc_growth", ax = axes[2,1])
sb.boxplot(data = player2[player2.age == 24], x = "start_rating", y = "perc_growth", ax = axes[3,0])
sb.boxplot(data = player2[player2.age == 25], x = "start_rating", y = "perc_growth", ax = axes[3,1])

# %%
f = plt.figure(figsize = (55,25))
sb.boxplot(data = player2[player2.age < 25], x = "start_rating", y = "max_rating")
plt.title("Peak Rating vs Initial Rating", fontsize = 70)
plt.xlabel("Initial Rating", fontsize = 70)
plt.ylabel("Peak Rating", fontsize = 70)
#plt.xticks(np.arange(0,93,5))
plt.tick_params(labelsize = 40)

# %%
player["start_rating"] = player["start_rating"].astype(int)

# %%
player.drop(axis = 1, labels = (183140, "start_rating") ,inplace = True)

# %%
player
# Out:
#         player_id        player_name   birthday  height  weight  birthyear  \
# 0            2625  Patryk Rachwal,18  1/27/1981  175.26     154       1981
# 1            2625  Patryk Rachwal,18  1/27/1981  175.26     154       1981
# 2            2625  Patryk Rachwal,18  1/27/1981  175.26     154       1981
# 3            2625  Patryk Rachwal,18  1/27/1981  175.26     154       1981
# 4            2625  Patryk Rachwal,18  1/27/1981  175.26     154       1981
# ...           ...                ...        ...     ...     ...        ...
# 183137     750435     Rees Greenwood  1/20/1996  172.72     150       1996
# 183138     750435     Rees Greenwood  1/20/1996  172.72     150       1996
# 183139     750435     Rees Greenwood  1/20/1996  172.72     150       1996
# 183140     750584  Alexandre Azevedo  1/28/1997  175.26     150       1997
# 183141     750584  Alexandre Azevedo  1/28/1997  175.26     150       1997
#
#         birthmonth       date  overall_rating  potential  ... month  \
# 0                1  1/16/2015              61         61  ...     1
# 1                1  11/7/2014              61         61  ...    11
# 2                1  9/18/2014              61         61  ...     9
# 3                1   6/7/2013              61         61  ...     6
# 4                1   3/8/2013              61         61  ...     3
# ...            ...        ...             ...        ...  ...   ...
# 183137           1   2/6/2015              56         70  ...     2
# 183138           1  1/16/2015              56         70  ...     1
# 183139           1  2/22/2007              56         70  ...     2
# 183140           1  5/19/2016              58         66  ...     5
# 183141           1  2/22/2007              58         66  ...     2
#
#               age age_rounded  max_rating  max_idx  max_age  abs_growth  \
# 0       34.000000          34          63   139855       27        -2.0
# 1       33.833333          34          63   139855       27        -2.0
# 2       33.666667          34          63   139855       27        -2.0
# 3       32.416667          32          63   139855       27        -2.0
# 4       32.166667          32          63   139855       27        -2.0
# ...           ...         ...         ...      ...      ...         ...
# 183137  19.083333          19          60   147408       20         0.0
# 183138  19.000000          19          60   147408       20         0.0
# 183139  11.083333          11          60   147408       20         0.0
# 183140  19.333333          19          58     8085       19         0.0
# 183141  10.083333          10          58     8085       19         0.0
#
#         perc_growth  year_elapsed  start_rating
# 0         -3.174603      7.916667            63
# 1         -3.174603      7.750000            63
# 2         -3.174603      7.583333            63
# 3         -3.174603      6.333333            63
# 4         -3.174603      6.083333            63
# ...             ...           ...           ...
# 183137     0.000000      8.000000            56
# 183138     0.000000      7.916667            56
# 183139     0.000000      0.000000            56
# 183140     0.000000      9.250000            58
# 183141     0.000000      0.000000            58
#
# [183142 rows x 57 columns]

# %%
player.to_csv("newplayer.csv", index = False)
